# %%
import matplotlib.pyplot as plt
import time

# %%
while True:
    with open("prob.txt", "r") as f:
        out = f.read().splitlines()
    m = []
    for i in out:
        m.append(float(i))
    print("number of minibatches passed ",len(m))
    print("avergae trust", sum(m)/len(m))
    plt.plot(m)
    plt.show()
    time.sleep(10)
# Out:
# number of minibatches passed  8095
# avergae trust 0.4592645186417776
# number of minibatches passed  8112
# avergae trust 0.4594700060880337
# number of minibatches passed  8130
# avergae trust 0.4596304691512353
